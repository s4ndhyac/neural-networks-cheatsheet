# %% [markdown]
# ## CS 273P Homework #1 (16th April 2019)
#
# ## Sandhya Chandramohan (Student ID: 61167891)
#
#
# ### 1: Python & Data Exploration

# %%
#Loading the data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)
iris = np.genfromtxt("data/iris.txt",delimiter=None) # load the text file
Y = iris[:,-1] # target value is the last column
X = iris[:,0:-1] # features are the other columns

# %%
#1. Get no. oof features and data points
print('Number of features: {0}'.format(X.shape[1]))
print('Number of data points: {0}'.format(X.shape[0]))
# Out:
# Number of features: 4
# Number of data points: 148

# %%
# 2. Plot a histogram of values for each feature
for i in range(0, 4):
    plt.hist(X[:, i], label='feature{}'.format(i+1))
    plt.legend()
    plt.show()
    plt.close()

# %%
# 3. Plot mean and standard deviation of each feature
for i in range(0, 4):
    print('\nMean of feature {}: {}'.format(i, np.mean(X[:, i])))
    print('Std of future {}: {}'.format(i, np.std(X[:, i])))
# Out:
# Mean of feature 0: 5.900103764189188
# Std of future 0: 0.833402066774894
#
# Mean of feature 1: 3.098930916891892
# Std of future 1: 0.43629183800107685
#
# Mean of feature 2: 3.8195548405405404
# Std of future 2: 1.7540571093439352
#
# Mean of feature 3: 1.2525554845945945
# Std of future 3: 0.7587724570263247

# %%
# 4. Plot a scatter plot for each pair of features colored according to their target value
length = X.shape[0]
featArray = [1, 2, 3]
for featNum in featArray:
    for i in range(0, length):
        if Y[i] == 0:
            plt.scatter(X[i, 0], X[i, featNum], c='b')
        if Y[i] == 1:
            plt.scatter(X[i, 0], X[i, featNum], c='g')
        if Y[i] == 2:
            plt.scatter(X[i, 0], X[i, featNum], c='r')
    plt.xlabel('feature1')
    plt.ylabel('feature{}'.format(featNum+1))
    plt.show()
    plt.close()
